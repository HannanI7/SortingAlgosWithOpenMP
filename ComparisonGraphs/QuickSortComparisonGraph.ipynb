# %%
import matplotlib.pyplot as plt
import numpy as np

# !rm -rf SortingAlgosWithOpenMP

# !git clone https://github.com/HannanI7/SortingAlgosWithOpenMP

# Navigate to the directory containing the C files
# %cd SortingAlgosWithOpenMP/QuickSortFolder

# Compile the non-OpenMP Quick sort program
# !gcc -o quick_sort Quick_Sort.c

# Compile the OpenMP Quick sort program
# !gcc -fopenmp -o quick_sort_openmp OpenMP_Quick_Sort.c

# Run the non-OpenMP program and time it
import time
start_time = time.time()
# !./quick_sort
end_time = time.time()
time_elapsed1 = end_time - start_time
print("Time elapsed for non-OpenMP Quick sort: ", time_elapsed1)

# Run the OpenMP program and time it
start_time = time.time()
# !./quick_sort_openmp
end_time = time.time()
time_elapsed2 = end_time - start_time
print("Time elapsed for OpenMP Quick sort: ", time_elapsed2)

# Define the data for the graph
labels = ['Non-OpenMP', 'OpenMP']
times = [time_elapsed1, time_elapsed2]

# Create a bar plot of the data
x_pos = np.arange(len(labels))
plt.bar(x_pos, times)
plt.xticks(x_pos, labels)
plt.ylabel('Time (seconds)')
plt.title('Quick Sort Comparison')

# Display the plot
plt.show()
# Out:
# Cloning into 'SortingAlgosWithOpenMP'...
# remote: Enumerating objects: 42, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 42 (delta 14), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (42/42), 115.53 KiB | 3.04 MiB/s, done.
# /content/SortingAlgosWithOpenMP/QuickSortFolder/SortingAlgosWithOpenMP/QuickSortFolder
# Quick_Sort.c: In function ‘main’:
# Quick_Sort.c:77:38: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘clock_t’ {aka ‘long int’} [-Wformat=]
#    77 |  printf("Initial time taken by CPU: %d \n", begin  );
#       |                                     ~^      ~~~~~
#       |                                      |      |
#       |                                      int    clock_t {aka long int}
#       |                                     %ld
# ...
