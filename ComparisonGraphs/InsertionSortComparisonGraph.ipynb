# %%
import matplotlib.pyplot as plt
import numpy as np

# !rm -rf SortingAlgosWithOpenMP

# !git clone https://github.com/HannanI7/SortingAlgosWithOpenMP

# Navigate to the directory containing the C files
# %cd SortingAlgosWithOpenMP/InsertionSortFolder

# Compile the non-OpenMP insertion sort program
# !gcc -o insertion_sort Insertion_Sort.c

# Compile the OpenMP insertion sort program
# !gcc -fopenmp -o insertion_sort_openmp OpenMP_Insertion_Sort.c

# Run the non-OpenMP program and time it
import time
start_time = time.time()
# !./insertion_sort
end_time = time.time()
time_elapsed1 = end_time - start_time
print("Time elapsed for non-OpenMP insertion sort: ", time_elapsed1)

# Run the OpenMP program and time it
start_time = time.time()
# !./insertion_sort_openmp
end_time = time.time()
time_elapsed2 = end_time - start_time
print("Time elapsed for OpenMP insertion sort: ", time_elapsed2)

# Define the data for the graph
labels = ['Non-OpenMP', 'OpenMP']
times = [time_elapsed1, time_elapsed2]

# Create a bar plot of the data
x_pos = np.arange(len(labels))
plt.bar(x_pos, times)
plt.xticks(x_pos, labels)
plt.ylabel('Time (seconds)')
plt.title('Insertion Sort Comparison')

# Display the plot
plt.show()
# Out:
# Cloning into 'SortingAlgosWithOpenMP'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 36 (delta 12), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (36/36), 114.11 KiB | 1.87 MiB/s, done.
# /content/SortingAlgosWithOpenMP/InsertionSortFolder
# Insertion_Sort.c: In function ‘main’:
# Insertion_Sort.c:55:41: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘clock_t’ {aka ‘long int’} [-Wformat=]
#    55 |     printf("Initial time taken by CPU: %d \n", begin  );
#       |                                        ~^      ~~~~~
#       |                                         |      |
#       |                                         int    clock_t {aka long int}
#       |                                        %ld
# ...
