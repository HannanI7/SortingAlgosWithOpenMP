# %%
import matplotlib.pyplot as plt
import numpy as np

# !rm -rf SortingAlgosWithOpenMP

# !git clone https://github.com/HannanI7/SortingAlgosWithOpenMP

# Navigate to the directory containing the C files
# %cd SortingAlgosWithOpenMP/BubbleSortFolder

# Compile the non-OpenMP bubble sort program
# !gcc -o bubble_sort Bubble_Sort.c

# Compile the OpenMP bubble sort program
# !gcc -fopenmp -o bubble_sort_openmp OpenMP_Bubble_Sort.c

# Run the non-OpenMP program and time it
import time
start_time = time.time()
# !./bubble_sort
end_time = time.time()
time_elapsed1 = end_time - start_time
print("Time elapsed for non-OpenMP bubble sort: ", time_elapsed1)

# Run the OpenMP program and time it
start_time = time.time()
# !./bubble_sort_openmp
end_time = time.time()
time_elapsed2 = end_time - start_time
print("Time elapsed for OpenMP bubble sort: ", time_elapsed2)

# Define the data for the graph
labels = ['Non-OpenMP', 'OpenMP']
times = [time_elapsed1, time_elapsed2]

# Create a bar plot of the data
x_pos = np.arange(len(labels))
plt.bar(x_pos, times)
plt.xticks(x_pos, labels)
plt.ylabel('Time (seconds)')
plt.title('Bubble Sort Comparison')

# Display the plot
plt.show()
# Out:
# Cloning into 'SortingAlgosWithOpenMP'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 27 (delta 8), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (27/27), 111.66 KiB | 944.00 KiB/s, done.
# /SortingAlgosWithOpenMP/BubbleSortFolder/SortingAlgosWithOpenMP/BubbleSortFolder/SortingAlgosWithOpenMP/BubbleSortFolder
# Bubble_Sort.c: In function ‘main’:
# Bubble_Sort.c:58:41: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘clock_t’ {aka ‘long int’} [-Wformat=]
#    58 |     printf("Initial time taken by CPU: %d \n", begin  );
#       |                                        ~^      ~~~~~
#       |                                         |      |
#       |                                         int    clock_t {aka long int}
#       |                                        %ld
# ...
